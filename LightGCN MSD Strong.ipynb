# %% [markdown]
# # LightGCN with MSD Dataset and StrongGeneralization Scenario

# %% [markdown]
# In this notebook, the implementation of LightGCN in RecPack and the experimental part to generate the results of the algorithm will be presented.
# The notebook contains:
# 1. The implementation of LightGCN in RecPack.
# 2. The 10% of MSD Dataset from RecPack and the StrongGeneralization Scenario has been used to split the data.
# 3. The StrongGeneralization Scenario to split the data.
# 4. The RecPack Pipeline Builder to run the experiments, including the splitted dataset, the algorithms and metrics to run. Hyperparameter has been performed in the Pipeline.
#
# Please make sure you have installed all the latest libraries in your Python environment, in order to have a successful run of the code.

# %%
# !pip install recpack

# %%
import torch
from tqdm import tqdm

# %%
from torch_sparse import SparseTensor, matmul

# %% [markdown]
# ## LightGCN implementation in RecPack

# %%
import torch
import torch.nn as nn
from torch_geometric.nn import MessagePassing
from torch_geometric.utils import add_self_loops, degree
import time
from typing import List, Tuple, Optional
from tqdm import tqdm
from recpack.algorithms.base import TorchMLAlgorithm
from recpack.matrix.interaction_matrix import InteractionMatrix
from recpack.matrix import to_csr_matrix
from recpack.algorithms.loss_functions import bpr_loss
from recpack.algorithms.samplers import PositiveNegativeSampler
from scipy.sparse import csr_matrix, lil_matrix
import torch.optim as optim
import logging

# logger = logging.getLogger(__name__)

# LightGCN model definition using MessagePassing from PyTorch Geometric
class LightGCN(MessagePassing):
    def __init__(self, num_users, num_items, embedding_dim=64, K=3, add_self_loops=False):
        """
        Initialize the LightGCN model with user and item embeddings.

        Args:
            num_users (int): Number of users.
            num_items (int): Number of items.
            embedding_dim (int): Dimension of the embedding vectors.
            K (int): Number of propagation layers.
            add_self_loops (bool): Whether to add self-loops to the adjacency matrix.
        """
        super(LightGCN, self).__init__(aggr='add')
        self.num_users, self.num_items = num_users, num_items
        self.embedding_dim, self.K = embedding_dim, K
        self.add_self_loops = add_self_loops

        # Initialize user and item embeddings
        self.users_emb = nn.Embedding(num_embeddings=self.num_users, embedding_dim=self.embedding_dim)
        self.items_emb = nn.Embedding(num_embeddings=self.num_items, embedding_dim=self.embedding_dim)

        # Initialize embeddings with normal distribution
        nn.init.normal_(self.users_emb.weight, std=0.1)
        nn.init.normal_(self.items_emb.weight, std=0.1)

    def forward(self, edge_index: SparseTensor):
        """
        Forward pass for the LightGCN model.

        Args:
            edge_index (SparseTensor): Sparse tensor representing the adjacency matrix.

        Returns:
            Tuple: Final user and item embeddings after propagation, and the initial embeddings.
        """
        if self.add_self_loops:
            edge_index, _ = add_self_loops(edge_index, num_nodes=self.num_users + self.num_items)
        
        # Normalize the adjacency matrix
        edge_index_norm = self.normalize_adj(edge_index)
        
        # Concatenate user and item embeddings
        emb_0 = torch.cat([self.users_emb.weight, self.items_emb.weight])
        embs = [emb_0]
        emb_k = emb_0

        # Perform K propagation steps
        for i in range(self.K):
            # Preventing CUDA/Library version error
            try:
                emb_k = self.propagate(edge_index_norm, x=emb_k)
            except RuntimeError as e:
                break
            embs.append(emb_k)

        # Stack and average embeddings from each propagation step
        embs = torch.stack(embs, dim=1)
        emb_final = torch.mean(embs, dim=1)

        # Split the final embeddings back into user and item embeddings
        users_emb_final, items_emb_final = torch.split(emb_final, [self.num_users, self.num_items])

        return users_emb_final, self.users_emb.weight, items_emb_final, self.items_emb.weight

    def message(self, x_j: torch.Tensor) -> torch.Tensor:
        """
        Message function that aggregates messages from neighboring nodes.

        Args:
            x_j (torch.Tensor): Features of the neighboring nodes.

        Returns:
            torch.Tensor: Aggregated messages.
        """
        return x_j

    def message_and_aggregate(self, adj_t: SparseTensor, x: torch.Tensor) -> torch.Tensor:
        """
        Message and aggregate function using matrix multiplication.

        Args:
            adj_t (SparseTensor): Transposed adjacency matrix.
            x (torch.Tensor): Node features.

        Returns:
            torch.Tensor: Result of multiplying adjacency matrix with node features.
        """
        return matmul(adj_t, x)

    def normalize_adj(self, edge_index: SparseTensor) -> SparseTensor:
        """
        Normalize the adjacency matrix.

        Args:
            edge_index (SparseTensor): Sparse tensor representing the adjacency matrix.

        Returns:
            SparseTensor: Normalized adjacency matrix.
        """
        row, col, value = edge_index.coo()
        row = row.long()  # Ensure indices are long type
        col = col.long()  # Ensure indices are long type
        deg = degree(row, num_nodes=edge_index.size(0), dtype=value.dtype)
        deg_inv_sqrt = deg.pow(-0.5)
        deg_inv_sqrt[deg_inv_sqrt == float('inf')] = 0
        value = deg_inv_sqrt[row] * value * deg_inv_sqrt[col]
        return SparseTensor(row=row, col=col, value=value, sparse_sizes=edge_index.sparse_sizes())

# %%
from recpack.algorithms.base import TorchMLAlgorithm
from recpack.matrix import Matrix
from recpack.matrix.interaction_matrix import InteractionMatrix
from recpack.algorithms.loss_functions import bpr_loss, bpr_max_loss
from recpack.algorithms.samplers import PositiveNegativeSampler
from recpack.algorithms.stopping_criterion import (
    EarlyStoppingException,
    StoppingCriterion,
)
from typing import List, Tuple, Optional
import numpy as np
from scipy.sparse import csr_matrix, lil_matrix, coo_matrix
import torch
import torch.optim as optim
import tempfile
import time
import logging

logger = logging.getLogger(__name__)

# Implementation of the LightGCN algorithm using TorchMLAlgorithm as a base class
class LightGCNAlgorithm(TorchMLAlgorithm):
    def __init__(
        self,
        batch_size: int = 256,
        max_epochs: int = 100,
        learning_rate: float = 0.001,
        embedding_dim: int = 64,
        n_layers: int = 3,
        reg_weight: float = 1e-5,
        stopping_criterion: str = "bpr",
        stop_early: bool = True,
        max_iter_no_change: int = 5,
        min_improvement: float = 0.01,
        seed: Optional[int] = None,
        save_best_to_file: bool = False,
        keep_last: bool = False,
        predict_topK: Optional[int] = None,
        validation_sample_size: Optional[int] = None,
    ):
        """
        Initialize the LightGCNAlgorithm with various hyperparameters.

        Args:
            batch_size (int): Number of samples per batch.
            max_epochs (int): Maximum number of training epochs.
            learning_rate (float): Learning rate for the optimizer.
            embedding_dim (int): Dimension of the embedding vectors.
            n_layers (int): Number of LightGCN layers.
            reg_weight (float): Regularization weight.
            stopping_criterion (str): Criterion to stop training early.
            stop_early (bool): Whether to enable early stopping.
            max_iter_no_change (int): Maximum iterations with no improvement for early stopping.
            min_improvement (float): Minimum improvement required for early stopping.
            seed (Optional[int]): Random seed for reproducibility.
            save_best_to_file (bool): Whether to save the best model to a file.
            keep_last (bool): Whether to keep the last model.
            predict_topK (Optional[int]): Number of top-K predictions to consider.
            validation_sample_size (Optional[int]): Size of the validation sample.
        """
        self.embedding_dim = embedding_dim
        self.n_layers = n_layers
        self.reg_weight = reg_weight
        super().__init__(
            batch_size=batch_size,
            max_epochs=max_epochs,
            learning_rate=learning_rate,
            stopping_criterion=stopping_criterion,
            stop_early=stop_early,
            max_iter_no_change=max_iter_no_change,
            min_improvement=min_improvement,
            seed=seed,
            save_best_to_file=save_best_to_file,
            keep_last=keep_last,
            predict_topK=predict_topK,
            validation_sample_size=validation_sample_size,
        )
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    def _init_model(self, train: InteractionMatrix) -> None:
        """
        Initialize the LightGCN model and optimizer.

        Args:
            train (InteractionMatrix): The training interaction matrix.
        """
        num_users, num_items = train.shape
        self.model_ = LightGCN(num_users, num_items, self.embedding_dim, self.n_layers).to(self.device)
        self.optimizer = optim.Adam(self.model_.parameters(), lr=self.learning_rate)

    def _create_sparse_graph(self, interaction_matrix: csr_matrix, num_users: int, num_items: int) -> SparseTensor:
        """
        Create a sparse graph from the interaction matrix.

        Args:
            interaction_matrix (csr_matrix): The interaction matrix in CSR format.
            num_users (int): Number of users.
            num_items (int): Number of items.

        Returns:
            SparseTensor: A sparse tensor representing the graph.
        """
        coo = interaction_matrix.tocoo()
        row = torch.tensor(coo.row, dtype=torch.long)
        col = torch.tensor(coo.col, dtype=torch.long)
        value = torch.tensor(coo.data, dtype=torch.float32)
        print(f"Graph - Rows: {row.shape}, Cols: {col.shape}, Values: {value.shape}")  # Debugging information
        return SparseTensor(row=row, col=col, value=value, sparse_sizes=(num_users + num_items, num_users + num_items)).to(self.device)

    def _train_epoch(self, train: csr_matrix) -> List[float]:
        """
        Train the model for one epoch.

        Args:
            train (csr_matrix): The training interaction matrix.

        Returns:
            List[float]: A list of losses for each batch.
        """
        self.model_.train()
        graph = self._create_sparse_graph(train, train.shape[0], train.shape[1]).to(self.device)
        total_loss = 0
        losses = []

        sampler = PositiveNegativeSampler(num_negatives=1, batch_size=self.batch_size)

        for user_indices, pos_item_indices, neg_item_indices in sampler.sample(train):
            user_indices = torch.tensor(user_indices).to(self.device)
            pos_item_indices = torch.tensor(pos_item_indices).to(self.device)
            neg_item_indices = torch.tensor(neg_item_indices).to(self.device).squeeze()

            self.optimizer.zero_grad()
            users_emb_final, _, items_emb_final, _ = self.model_(graph)  # Call model only once
            pos_scores = users_emb_final[user_indices] @ items_emb_final[pos_item_indices].t()
            neg_scores = users_emb_final[user_indices] @ items_emb_final[neg_item_indices].t()

            loss = bpr_loss(pos_scores, neg_scores)

            if torch.isnan(loss).any() or torch.isinf(loss).any():
                continue

            loss.backward()
            torch.nn.utils.clip_grad_norm_(self.model_.parameters(), max_norm=1.0)  # Gradient clipping
            self.optimizer.step()

            total_loss += loss.item()
            losses.append(loss.item())

        if len(losses) == 0:
            return [float('nan')]

        return losses

    def _batch_predict(self, X: csr_matrix, users: List[int]) -> csr_matrix:
        """
        Make batch predictions for a list of users.

        Args:
            X (csr_matrix): The interaction matrix.
            users (List[int]): List of user indices to make predictions for.

        Returns:
            csr_matrix: A sparse matrix with the prediction scores.
        """
        self.model_.eval()
        graph = self._create_sparse_graph(X, X.shape[0], X.shape[1]).to(self.device)
        user_indices = torch.tensor(users).to(self.device)
        item_indices = torch.arange(X.shape[1]).to(self.device)
        
        with torch.no_grad():
            user_emb_final, _, item_emb_final, _ = self.model_(graph)
            scores = user_emb_final[user_indices] @ item_emb_final.t()
            scores = scores.cpu().numpy()
        
        result = lil_matrix((X.shape[0], X.shape[1]))
        for i, user in enumerate(users):
            result[user] = scores[i]
        
        return result.tocsr()

    def fit(self, X: csr_matrix, validation_data: tuple):
        """
        Fit the model to the training data.

        Args:
            X (csr_matrix): The training interaction matrix.
            validation_data (tuple): Validation data used for early stopping.
        """
        super().fit(X, validation_data)

# %%
from recpack.datasets import Netflix, DummyDataset
from recpack.pipelines import PipelineBuilder
from recpack.scenarios import StrongGeneralization
from recpack.pipelines import ALGORITHM_REGISTRY
import pandas as pd

# %%
ALGORITHM_REGISTRY.register("LightGCNAlgorithm", LightGCNAlgorithm)

# %% [markdown]
# ## RecPack Dataset Importing

# %%
from recpack.datasets import MillionSongDataset
dataset = MillionSongDataset()

# %%
dataset.fetch_dataset()

# %%
dataset

# %%
df = dataset._load_dataframe()

# %% [markdown]
# ## Datasets without Timestamps sampling

# %%
# Count interactions per user and per song
user_interactions = df['userId'].value_counts().reset_index()
user_interactions.columns = ['userId', 'user_interactions']

song_interactions = df['songId'].value_counts().reset_index()
song_interactions.columns = ['songId', 'song_interactions']

# Merge the interaction counts back to the original dataframe
df = df.merge(user_interactions, on='userId')
df = df.merge(song_interactions, on='songId')

# Calculate a combined interaction score
df['interaction_score'] = df['user_interactions'] + df['song_interactions']

# Rank based on the interaction score
df['rank'] = df['interaction_score'].rank(method='first', ascending=False)

# Select the top 10%
filtered_df = df[df['rank'] <= len(df) * 0.1]

# Drop helper columns
filtered_df = filtered_df.drop(columns=['user_interactions', 'song_interactions', 'interaction_score', 'rank'])

# %%
df
# Out:
#                                              userId              songId
# 0          b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995
# 1          b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAPDEY12A81C210A9
# 2          b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B
# 3          b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B
# 4          b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBFNSP12AF72A0E22
# ...                                             ...                 ...
# 138680238  b7815dbb206eb2831ce0fe040d0aa537e2e800f7  SOUSMXX12AB0185C24
# 138680239  b7815dbb206eb2831ce0fe040d0aa537e2e800f7  SOWYSKH12AF72A303A
# 138680240  b7815dbb206eb2831ce0fe040d0aa537e2e800f7  SOWYSKH12AF72A303A
# 138680241  b7815dbb206eb2831ce0fe040d0aa537e2e800f7  SOWYSKH12AF72A303A
# 138680242  b7815dbb206eb2831ce0fe040d0aa537e2e800f7  SOYYFLV12A58A7A88F
#
# [138680243 rows x 2 columns]

# %%
filtered_df
# Out:
#                                              userId              songId
# 28         b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOFRQTD12A81C233C0
# 59         b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOMGIYR12AB0187973
# 60         b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOMGIYR12AB0187973
# 61         b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOMGIYR12AB0187973
# 62         b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOMGIYR12AB0187973
# ...                                             ...                 ...
# 138680210  b7815dbb206eb2831ce0fe040d0aa537e2e800f7  SOOFYTN12A6D4F9B35
# 138680211  b7815dbb206eb2831ce0fe040d0aa537e2e800f7  SOOFYTN12A6D4F9B35
# 138680212  b7815dbb206eb2831ce0fe040d0aa537e2e800f7  SOOFYTN12A6D4F9B35
# 138680237  b7815dbb206eb2831ce0fe040d0aa537e2e800f7  SOUJVIT12A8C1451C1
# 138680238  b7815dbb206eb2831ce0fe040d0aa537e2e800f7  SOUSMXX12AB0185C24
#
# [13868024 rows x 2 columns]

# %% [markdown]
# ## Dataset Preprocessing to Interaction Matrix

# %%
from recpack.matrix import InteractionMatrix
from recpack.preprocessing.preprocessors import DataFramePreprocessor
item_ix = 'songId'
user_ix = 'userId'

preprocessor = DataFramePreprocessor(item_ix=item_ix, user_ix=user_ix)
interaction_matrix = preprocessor.process(filtered_df)
# Out:
#   0%|          | 0/13868024 [00:00<?, ?it/s]
#   0%|          | 0/13868024 [00:00<?, ?it/s]

# %%
interaction_matrix.values
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int32'
# 	with 3387777 stored elements and shape (663854, 127)>

# %%
interaction_matrix.num_interactions
# Out:
# 13868024

# %%
interaction_matrix.properties
# Out:
# InteractionMatrix.InteractionMatrixProperties(num_users=663854, num_items=127, has_timestamps=False)

# %% [markdown]
# ## StrongGeneralization Scenario Splitting of Data

# %%
scenario = StrongGeneralization(frac_users_train=0.8, frac_interactions_in=0.8, validation=True)
scenario.split(interaction_matrix)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %% [markdown]
# ## Experimental RecPack Pipeline

# %%
pipeline_builder = PipelineBuilder()
ok = (scenario._validation_data_in, scenario._validation_data_out)
pipeline_builder.set_data_from_scenario(scenario)


# Add the baseline algorithms
#pipeline_builder.add_algorithm('ItemKNN', grid={'K': [100, 200, 400, 800]})
#pipeline_builder.add_algorithm('EASE', grid={'l2': [10, 100, 1000], 'alpha': [0, 0.1, 0.5]})

# Add our LightGCN algorithm
pipeline_builder.add_algorithm(
    'LightGCNAlgorithm',
    grid={
        'learning_rate': [0.1, 0.01, 0.001],
        'embedding_dim': [100, 200, 400]
    },
    params={
        'max_epochs': 5,
        'batch_size': 1024,
        'n_layers': 3
    }
)

# Add NDCG, Recall, and HR metrics to be evaluated at 10, 20, and 50
pipeline_builder.add_metric('NDCGK', [10, 20, 50])
pipeline_builder.add_metric('RecallK', [10, 20, 50])
pipeline_builder.add_metric('HitK', [10, 20, 50])

# Set the optimisation metric
pipeline_builder.set_optimisation_metric('RecallK', 20)

# Construct pipeline
pipeline = pipeline_builder.build()

# Run pipeline, will first do optimisation, and then evaluation
pipeline.run()
# Out:
# /opt/conda/lib/python3.11/site-packages/recpack/pipelines/pipeline_builder.py:145: UserWarning: Grid parameter for add_algorithm function will be deprecated in favour of optimisation_info.
#   warnings.warn(
#   0%|          | 0/1 [00:00<?, ?it/s]
# Graph - Rows: torch.Size([1891951]), Cols: torch.Size([1891951]), Values: torch.Size([1891951])
# /tmp/ipykernel_173/999541933.py:81: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   user_indices = torch.tensor(user_indices).to(self.device)
# /tmp/ipykernel_173/999541933.py:82: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pos_item_indices = torch.tensor(pos_item_indices).to(self.device)
# /tmp/ipykernel_173/999541933.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   neg_item_indices = torch.tensor(neg_item_indices).to(self.device).squeeze()
# 2024-07-31 07:09:42,201 - base - recpack - INFO - Processed epoch 0 in 30.07 s.Batch Training Loss = 0.6258
# Graph - Rows: torch.Size([6752]), Cols: torch.Size([6752]), Values: torch.Size([6752])
# Graph - Rows: torch.Size([6361]), Cols: torch.Size([6361]), Values: torch.Size([6361])
# Graph - Rows: torch.Size([6575]), Cols: torch.Size([6575]), Values: torch.Size([6575])
# Graph - Rows: torch.Size([6928]), Cols: torch.Size([6928]), Values: torch.Size([6928])
# Graph - Rows: torch.Size([7263]), Cols: torch.Size([7263]), Values: torch.Size([7263])
# Graph - Rows: torch.Size([6850]), Cols: torch.Size([6850]), Values: torch.Size([6850])
# Graph - Rows: torch.Size([6858]), Cols: torch.Size([6858]), Values: torch.Size([6858])
# Graph - Rows: torch.Size([6815]), Cols: torch.Size([6815]), Values: torch.Size([6815])
# Graph - Rows: torch.Size([6797]), Cols: torch.Size([6797]), Values: torch.Size([6797])
# Graph - Rows: torch.Size([6403]), Cols: torch.Size([6403]), Values: torch.Size([6403])
# Graph - Rows: torch.Size([7028]), Cols: torch.Size([7028]), Values: torch.Size([7028])
# Graph - Rows: torch.Size([6895]), Cols: torch.Size([6895]), Values: torch.Size([6895])
# Graph - Rows: torch.Size([6389]), Cols: torch.Size([6389]), Values: torch.Size([6389])
# Graph - Rows: torch.Size([6855]), Cols: torch.Size([6855]), Values: torch.Size([6855])
# Graph - Rows: torch.Size([6856]), Cols: torch.Size([6856]), Values: torch.Size([6856])
# Graph - Rows: torch.Size([7066]), Cols: torch.Size([7066]), Values: torch.Size([7066])
# Graph - Rows: torch.Size([6985]), Cols: torch.Size([6985]), Values: torch.Size([6985])
# Graph - Rows: torch.Size([6623]), Cols: torch.Size([6623]), Values: torch.Size([6623])
# Graph - Rows: torch.Size([6701]), Cols: torch.Size([6701]), Values: torch.Size([6701])
# Graph - Rows: torch.Size([6904]), Cols: torch.Size([6904]), Values: torch.Size([6904])
# Graph - Rows: torch.Size([6693]), Cols: torch.Size([6693]), Values: torch.Size([6693])
# Graph - Rows: torch.Size([6998]), Cols: torch.Size([6998]), Values: torch.Size([6998])
# Graph - Rows: torch.Size([6817]), Cols: torch.Size([6817]), Values: torch.Size([6817])
# Graph - Rows: torch.Size([6873]), Cols: torch.Size([6873]), Values: torch.Size([6873])
# Graph - Rows: torch.Size([6407]), Cols: torch.Size([6407]), Values: torch.Size([6407])
# Graph - Rows: torch.Size([6966]), Cols: torch.Size([6966]), Values: torch.Size([6966])
# Graph - Rows: torch.Size([6498]), Cols: torch.Size([6498]), Values: torch.Size([6498])
# Graph - Rows: torch.Size([6480]), Cols: torch.Size([6480]), Values: torch.Size([6480])
# Graph - Rows: torch.Size([6669]), Cols: torch.Size([6669]), Values: torch.Size([6669])
# Graph - Rows: torch.Size([7034]), Cols: torch.Size([7034]), Values: torch.Size([7034])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([7106]), Cols: torch.Size([7106]), Values: torch.Size([7106])
# Graph - Rows: torch.Size([6859]), Cols: torch.Size([6859]), Values: torch.Size([6859])
# Graph - Rows: torch.Size([6339]), Cols: torch.Size([6339]), Values: torch.Size([6339])
# Graph - Rows: torch.Size([7157]), Cols: torch.Size([7157]), Values: torch.Size([7157])
# Graph - Rows: torch.Size([6950]), Cols: torch.Size([6950]), Values: torch.Size([6950])
# Graph - Rows: torch.Size([6956]), Cols: torch.Size([6956]), Values: torch.Size([6956])
# Graph - Rows: torch.Size([6444]), Cols: torch.Size([6444]), Values: torch.Size([6444])
# Graph - Rows: torch.Size([6706]), Cols: torch.Size([6706]), Values: torch.Size([6706])
# Graph - Rows: torch.Size([6682]), Cols: torch.Size([6682]), Values: torch.Size([6682])
# Graph - Rows: torch.Size([6816]), Cols: torch.Size([6816]), Values: torch.Size([6816])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([7250]), Cols: torch.Size([7250]), Values: torch.Size([7250])
# Graph - Rows: torch.Size([7251]), Cols: torch.Size([7251]), Values: torch.Size([7251])
# Graph - Rows: torch.Size([6615]), Cols: torch.Size([6615]), Values: torch.Size([6615])
# Graph - Rows: torch.Size([7236]), Cols: torch.Size([7236]), Values: torch.Size([7236])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([7087]), Cols: torch.Size([7087]), Values: torch.Size([7087])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([6916]), Cols: torch.Size([6916]), Values: torch.Size([6916])
# Graph - Rows: torch.Size([6942]), Cols: torch.Size([6942]), Values: torch.Size([6942])
# Graph - Rows: torch.Size([6767]), Cols: torch.Size([6767]), Values: torch.Size([6767])
# Graph - Rows: torch.Size([7144]), Cols: torch.Size([7144]), Values: torch.Size([7144])
# Graph - Rows: torch.Size([6737]), Cols: torch.Size([6737]), Values: torch.Size([6737])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([6574]), Cols: torch.Size([6574]), Values: torch.Size([6574])
# Graph - Rows: torch.Size([2845]), Cols: torch.Size([2845]), Values: torch.Size([2845])
# 2024-07-31 07:12:47,779 - stopping_criterion - recpack - INFO - StoppingCriterion has value 0.7026629422903026, which is better than previous iterations.
# 2024-07-31 07:12:47,779 - base - recpack - INFO - Model improved. Storing better model.
# 2024-07-31 07:12:48,438 - base - recpack - INFO - Evaluation at end of 0 took 186.23 s.
# Graph - Rows: torch.Size([1891951]), Cols: torch.Size([1891951]), Values: torch.Size([1891951])
# 2024-07-31 07:13:18,493 - base - recpack - INFO - Processed epoch 1 in 30.05 s.Batch Training Loss = 0.5769
# Graph - Rows: torch.Size([6752]), Cols: torch.Size([6752]), Values: torch.Size([6752])
# Graph - Rows: torch.Size([6361]), Cols: torch.Size([6361]), Values: torch.Size([6361])
# Graph - Rows: torch.Size([6575]), Cols: torch.Size([6575]), Values: torch.Size([6575])
# Graph - Rows: torch.Size([6928]), Cols: torch.Size([6928]), Values: torch.Size([6928])
# Graph - Rows: torch.Size([7263]), Cols: torch.Size([7263]), Values: torch.Size([7263])
# Graph - Rows: torch.Size([6850]), Cols: torch.Size([6850]), Values: torch.Size([6850])
# Graph - Rows: torch.Size([6858]), Cols: torch.Size([6858]), Values: torch.Size([6858])
# Graph - Rows: torch.Size([6815]), Cols: torch.Size([6815]), Values: torch.Size([6815])
# Graph - Rows: torch.Size([6797]), Cols: torch.Size([6797]), Values: torch.Size([6797])
# Graph - Rows: torch.Size([6403]), Cols: torch.Size([6403]), Values: torch.Size([6403])
# Graph - Rows: torch.Size([7028]), Cols: torch.Size([7028]), Values: torch.Size([7028])
# Graph - Rows: torch.Size([6895]), Cols: torch.Size([6895]), Values: torch.Size([6895])
# Graph - Rows: torch.Size([6389]), Cols: torch.Size([6389]), Values: torch.Size([6389])
# Graph - Rows: torch.Size([6855]), Cols: torch.Size([6855]), Values: torch.Size([6855])
# Graph - Rows: torch.Size([6856]), Cols: torch.Size([6856]), Values: torch.Size([6856])
# Graph - Rows: torch.Size([7066]), Cols: torch.Size([7066]), Values: torch.Size([7066])
# Graph - Rows: torch.Size([6985]), Cols: torch.Size([6985]), Values: torch.Size([6985])
# Graph - Rows: torch.Size([6623]), Cols: torch.Size([6623]), Values: torch.Size([6623])
# Graph - Rows: torch.Size([6701]), Cols: torch.Size([6701]), Values: torch.Size([6701])
# Graph - Rows: torch.Size([6904]), Cols: torch.Size([6904]), Values: torch.Size([6904])
# Graph - Rows: torch.Size([6693]), Cols: torch.Size([6693]), Values: torch.Size([6693])
# Graph - Rows: torch.Size([6998]), Cols: torch.Size([6998]), Values: torch.Size([6998])
# Graph - Rows: torch.Size([6817]), Cols: torch.Size([6817]), Values: torch.Size([6817])
# Graph - Rows: torch.Size([6873]), Cols: torch.Size([6873]), Values: torch.Size([6873])
# Graph - Rows: torch.Size([6407]), Cols: torch.Size([6407]), Values: torch.Size([6407])
# Graph - Rows: torch.Size([6966]), Cols: torch.Size([6966]), Values: torch.Size([6966])
# Graph - Rows: torch.Size([6498]), Cols: torch.Size([6498]), Values: torch.Size([6498])
# Graph - Rows: torch.Size([6480]), Cols: torch.Size([6480]), Values: torch.Size([6480])
# Graph - Rows: torch.Size([6669]), Cols: torch.Size([6669]), Values: torch.Size([6669])
# Graph - Rows: torch.Size([7034]), Cols: torch.Size([7034]), Values: torch.Size([7034])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([7106]), Cols: torch.Size([7106]), Values: torch.Size([7106])
# Graph - Rows: torch.Size([6859]), Cols: torch.Size([6859]), Values: torch.Size([6859])
# Graph - Rows: torch.Size([6339]), Cols: torch.Size([6339]), Values: torch.Size([6339])
# Graph - Rows: torch.Size([7157]), Cols: torch.Size([7157]), Values: torch.Size([7157])
# Graph - Rows: torch.Size([6950]), Cols: torch.Size([6950]), Values: torch.Size([6950])
# Graph - Rows: torch.Size([6956]), Cols: torch.Size([6956]), Values: torch.Size([6956])
# Graph - Rows: torch.Size([6444]), Cols: torch.Size([6444]), Values: torch.Size([6444])
# Graph - Rows: torch.Size([6706]), Cols: torch.Size([6706]), Values: torch.Size([6706])
# Graph - Rows: torch.Size([6682]), Cols: torch.Size([6682]), Values: torch.Size([6682])
# Graph - Rows: torch.Size([6816]), Cols: torch.Size([6816]), Values: torch.Size([6816])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([7250]), Cols: torch.Size([7250]), Values: torch.Size([7250])
# Graph - Rows: torch.Size([7251]), Cols: torch.Size([7251]), Values: torch.Size([7251])
# Graph - Rows: torch.Size([6615]), Cols: torch.Size([6615]), Values: torch.Size([6615])
# Graph - Rows: torch.Size([7236]), Cols: torch.Size([7236]), Values: torch.Size([7236])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([7087]), Cols: torch.Size([7087]), Values: torch.Size([7087])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([6916]), Cols: torch.Size([6916]), Values: torch.Size([6916])
# Graph - Rows: torch.Size([6942]), Cols: torch.Size([6942]), Values: torch.Size([6942])
# Graph - Rows: torch.Size([6767]), Cols: torch.Size([6767]), Values: torch.Size([6767])
# Graph - Rows: torch.Size([7144]), Cols: torch.Size([7144]), Values: torch.Size([7144])
# Graph - Rows: torch.Size([6737]), Cols: torch.Size([6737]), Values: torch.Size([6737])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([6574]), Cols: torch.Size([6574]), Values: torch.Size([6574])
# Graph - Rows: torch.Size([2845]), Cols: torch.Size([2845]), Values: torch.Size([2845])
# 2024-07-31 07:16:30,631 - stopping_criterion - recpack - INFO - StoppingCriterion has value 0.7161144936923028, which is worse than previous iterations.
# 2024-07-31 07:16:30,633 - base - recpack - INFO - Evaluation at end of 1 took 192.14 s.
# Graph - Rows: torch.Size([1891951]), Cols: torch.Size([1891951]), Values: torch.Size([1891951])
# 2024-07-31 07:17:00,461 - base - recpack - INFO - Processed epoch 2 in 29.83 s.Batch Training Loss = 0.5746
# Graph - Rows: torch.Size([6752]), Cols: torch.Size([6752]), Values: torch.Size([6752])
# Graph - Rows: torch.Size([6361]), Cols: torch.Size([6361]), Values: torch.Size([6361])
# Graph - Rows: torch.Size([6575]), Cols: torch.Size([6575]), Values: torch.Size([6575])
# Graph - Rows: torch.Size([6928]), Cols: torch.Size([6928]), Values: torch.Size([6928])
# Graph - Rows: torch.Size([7263]), Cols: torch.Size([7263]), Values: torch.Size([7263])
# Graph - Rows: torch.Size([6850]), Cols: torch.Size([6850]), Values: torch.Size([6850])
# Graph - Rows: torch.Size([6858]), Cols: torch.Size([6858]), Values: torch.Size([6858])
# Graph - Rows: torch.Size([6815]), Cols: torch.Size([6815]), Values: torch.Size([6815])
# Graph - Rows: torch.Size([6797]), Cols: torch.Size([6797]), Values: torch.Size([6797])
# Graph - Rows: torch.Size([6403]), Cols: torch.Size([6403]), Values: torch.Size([6403])
# Graph - Rows: torch.Size([7028]), Cols: torch.Size([7028]), Values: torch.Size([7028])
# Graph - Rows: torch.Size([6895]), Cols: torch.Size([6895]), Values: torch.Size([6895])
# Graph - Rows: torch.Size([6389]), Cols: torch.Size([6389]), Values: torch.Size([6389])
# Graph - Rows: torch.Size([6855]), Cols: torch.Size([6855]), Values: torch.Size([6855])
# Graph - Rows: torch.Size([6856]), Cols: torch.Size([6856]), Values: torch.Size([6856])
# Graph - Rows: torch.Size([7066]), Cols: torch.Size([7066]), Values: torch.Size([7066])
# Graph - Rows: torch.Size([6985]), Cols: torch.Size([6985]), Values: torch.Size([6985])
# Graph - Rows: torch.Size([6623]), Cols: torch.Size([6623]), Values: torch.Size([6623])
# Graph - Rows: torch.Size([6701]), Cols: torch.Size([6701]), Values: torch.Size([6701])
# Graph - Rows: torch.Size([6904]), Cols: torch.Size([6904]), Values: torch.Size([6904])
# Graph - Rows: torch.Size([6693]), Cols: torch.Size([6693]), Values: torch.Size([6693])
# Graph - Rows: torch.Size([6998]), Cols: torch.Size([6998]), Values: torch.Size([6998])
# Graph - Rows: torch.Size([6817]), Cols: torch.Size([6817]), Values: torch.Size([6817])
# Graph - Rows: torch.Size([6873]), Cols: torch.Size([6873]), Values: torch.Size([6873])
# Graph - Rows: torch.Size([6407]), Cols: torch.Size([6407]), Values: torch.Size([6407])
# Graph - Rows: torch.Size([6966]), Cols: torch.Size([6966]), Values: torch.Size([6966])
# Graph - Rows: torch.Size([6498]), Cols: torch.Size([6498]), Values: torch.Size([6498])
# Graph - Rows: torch.Size([6480]), Cols: torch.Size([6480]), Values: torch.Size([6480])
# Graph - Rows: torch.Size([6669]), Cols: torch.Size([6669]), Values: torch.Size([6669])
# Graph - Rows: torch.Size([7034]), Cols: torch.Size([7034]), Values: torch.Size([7034])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([7106]), Cols: torch.Size([7106]), Values: torch.Size([7106])
# Graph - Rows: torch.Size([6859]), Cols: torch.Size([6859]), Values: torch.Size([6859])
# Graph - Rows: torch.Size([6339]), Cols: torch.Size([6339]), Values: torch.Size([6339])
# Graph - Rows: torch.Size([7157]), Cols: torch.Size([7157]), Values: torch.Size([7157])
# Graph - Rows: torch.Size([6950]), Cols: torch.Size([6950]), Values: torch.Size([6950])
# Graph - Rows: torch.Size([6956]), Cols: torch.Size([6956]), Values: torch.Size([6956])
# Graph - Rows: torch.Size([6444]), Cols: torch.Size([6444]), Values: torch.Size([6444])
# Graph - Rows: torch.Size([6706]), Cols: torch.Size([6706]), Values: torch.Size([6706])
# Graph - Rows: torch.Size([6682]), Cols: torch.Size([6682]), Values: torch.Size([6682])
# Graph - Rows: torch.Size([6816]), Cols: torch.Size([6816]), Values: torch.Size([6816])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([7250]), Cols: torch.Size([7250]), Values: torch.Size([7250])
# Graph - Rows: torch.Size([7251]), Cols: torch.Size([7251]), Values: torch.Size([7251])
# Graph - Rows: torch.Size([6615]), Cols: torch.Size([6615]), Values: torch.Size([6615])
# Graph - Rows: torch.Size([7236]), Cols: torch.Size([7236]), Values: torch.Size([7236])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([7087]), Cols: torch.Size([7087]), Values: torch.Size([7087])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([6916]), Cols: torch.Size([6916]), Values: torch.Size([6916])
# Graph - Rows: torch.Size([6942]), Cols: torch.Size([6942]), Values: torch.Size([6942])
# Graph - Rows: torch.Size([6767]), Cols: torch.Size([6767]), Values: torch.Size([6767])
# Graph - Rows: torch.Size([7144]), Cols: torch.Size([7144]), Values: torch.Size([7144])
# Graph - Rows: torch.Size([6737]), Cols: torch.Size([6737]), Values: torch.Size([6737])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([6574]), Cols: torch.Size([6574]), Values: torch.Size([6574])
# Graph - Rows: torch.Size([2845]), Cols: torch.Size([2845]), Values: torch.Size([2845])
# 2024-07-31 07:20:13,792 - stopping_criterion - recpack - INFO - StoppingCriterion has value 0.7277330648158494, which is worse than previous iterations.
# 2024-07-31 07:20:13,794 - base - recpack - INFO - Evaluation at end of 2 took 193.33 s.
# Graph - Rows: torch.Size([1891951]), Cols: torch.Size([1891951]), Values: torch.Size([1891951])
# 2024-07-31 07:20:43,449 - base - recpack - INFO - Processed epoch 3 in 29.65 s.Batch Training Loss = 0.5806
# Graph - Rows: torch.Size([6752]), Cols: torch.Size([6752]), Values: torch.Size([6752])
# Graph - Rows: torch.Size([6361]), Cols: torch.Size([6361]), Values: torch.Size([6361])
# Graph - Rows: torch.Size([6575]), Cols: torch.Size([6575]), Values: torch.Size([6575])
# Graph - Rows: torch.Size([6928]), Cols: torch.Size([6928]), Values: torch.Size([6928])
# Graph - Rows: torch.Size([7263]), Cols: torch.Size([7263]), Values: torch.Size([7263])
# Graph - Rows: torch.Size([6850]), Cols: torch.Size([6850]), Values: torch.Size([6850])
# Graph - Rows: torch.Size([6858]), Cols: torch.Size([6858]), Values: torch.Size([6858])
# Graph - Rows: torch.Size([6815]), Cols: torch.Size([6815]), Values: torch.Size([6815])
# Graph - Rows: torch.Size([6797]), Cols: torch.Size([6797]), Values: torch.Size([6797])
# Graph - Rows: torch.Size([6403]), Cols: torch.Size([6403]), Values: torch.Size([6403])
# Graph - Rows: torch.Size([7028]), Cols: torch.Size([7028]), Values: torch.Size([7028])
# Graph - Rows: torch.Size([6895]), Cols: torch.Size([6895]), Values: torch.Size([6895])
# Graph - Rows: torch.Size([6389]), Cols: torch.Size([6389]), Values: torch.Size([6389])
# Graph - Rows: torch.Size([6855]), Cols: torch.Size([6855]), Values: torch.Size([6855])
# Graph - Rows: torch.Size([6856]), Cols: torch.Size([6856]), Values: torch.Size([6856])
# Graph - Rows: torch.Size([7066]), Cols: torch.Size([7066]), Values: torch.Size([7066])
# Graph - Rows: torch.Size([6985]), Cols: torch.Size([6985]), Values: torch.Size([6985])
# Graph - Rows: torch.Size([6623]), Cols: torch.Size([6623]), Values: torch.Size([6623])
# Graph - Rows: torch.Size([6701]), Cols: torch.Size([6701]), Values: torch.Size([6701])
# Graph - Rows: torch.Size([6904]), Cols: torch.Size([6904]), Values: torch.Size([6904])
# Graph - Rows: torch.Size([6693]), Cols: torch.Size([6693]), Values: torch.Size([6693])
# Graph - Rows: torch.Size([6998]), Cols: torch.Size([6998]), Values: torch.Size([6998])
# Graph - Rows: torch.Size([6817]), Cols: torch.Size([6817]), Values: torch.Size([6817])
# Graph - Rows: torch.Size([6873]), Cols: torch.Size([6873]), Values: torch.Size([6873])
# Graph - Rows: torch.Size([6407]), Cols: torch.Size([6407]), Values: torch.Size([6407])
# Graph - Rows: torch.Size([6966]), Cols: torch.Size([6966]), Values: torch.Size([6966])
# Graph - Rows: torch.Size([6498]), Cols: torch.Size([6498]), Values: torch.Size([6498])
# Graph - Rows: torch.Size([6480]), Cols: torch.Size([6480]), Values: torch.Size([6480])
# Graph - Rows: torch.Size([6669]), Cols: torch.Size([6669]), Values: torch.Size([6669])
# Graph - Rows: torch.Size([7034]), Cols: torch.Size([7034]), Values: torch.Size([7034])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([7106]), Cols: torch.Size([7106]), Values: torch.Size([7106])
# Graph - Rows: torch.Size([6859]), Cols: torch.Size([6859]), Values: torch.Size([6859])
# Graph - Rows: torch.Size([6339]), Cols: torch.Size([6339]), Values: torch.Size([6339])
# Graph - Rows: torch.Size([7157]), Cols: torch.Size([7157]), Values: torch.Size([7157])
# Graph - Rows: torch.Size([6950]), Cols: torch.Size([6950]), Values: torch.Size([6950])
# Graph - Rows: torch.Size([6956]), Cols: torch.Size([6956]), Values: torch.Size([6956])
# Graph - Rows: torch.Size([6444]), Cols: torch.Size([6444]), Values: torch.Size([6444])
# Graph - Rows: torch.Size([6706]), Cols: torch.Size([6706]), Values: torch.Size([6706])
# Graph - Rows: torch.Size([6682]), Cols: torch.Size([6682]), Values: torch.Size([6682])
# Graph - Rows: torch.Size([6816]), Cols: torch.Size([6816]), Values: torch.Size([6816])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([7250]), Cols: torch.Size([7250]), Values: torch.Size([7250])
# Graph - Rows: torch.Size([7251]), Cols: torch.Size([7251]), Values: torch.Size([7251])
# Graph - Rows: torch.Size([6615]), Cols: torch.Size([6615]), Values: torch.Size([6615])
# Graph - Rows: torch.Size([7236]), Cols: torch.Size([7236]), Values: torch.Size([7236])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([7087]), Cols: torch.Size([7087]), Values: torch.Size([7087])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([6916]), Cols: torch.Size([6916]), Values: torch.Size([6916])
# Graph - Rows: torch.Size([6942]), Cols: torch.Size([6942]), Values: torch.Size([6942])
# Graph - Rows: torch.Size([6767]), Cols: torch.Size([6767]), Values: torch.Size([6767])
# Graph - Rows: torch.Size([7144]), Cols: torch.Size([7144]), Values: torch.Size([7144])
# Graph - Rows: torch.Size([6737]), Cols: torch.Size([6737]), Values: torch.Size([6737])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([6574]), Cols: torch.Size([6574]), Values: torch.Size([6574])
# Graph - Rows: torch.Size([2845]), Cols: torch.Size([2845]), Values: torch.Size([2845])
# 2024-07-31 07:23:57,332 - stopping_criterion - recpack - INFO - StoppingCriterion has value 0.7242235780059304, which is worse than previous iterations.
# 2024-07-31 07:23:57,334 - base - recpack - INFO - Evaluation at end of 3 took 193.88 s.
# Graph - Rows: torch.Size([1891951]), Cols: torch.Size([1891951]), Values: torch.Size([1891951])
# 2024-07-31 07:24:26,952 - base - recpack - INFO - Processed epoch 4 in 29.62 s.Batch Training Loss = 0.5840
# Graph - Rows: torch.Size([6752]), Cols: torch.Size([6752]), Values: torch.Size([6752])
# Graph - Rows: torch.Size([6361]), Cols: torch.Size([6361]), Values: torch.Size([6361])
# Graph - Rows: torch.Size([6575]), Cols: torch.Size([6575]), Values: torch.Size([6575])
# Graph - Rows: torch.Size([6928]), Cols: torch.Size([6928]), Values: torch.Size([6928])
# Graph - Rows: torch.Size([7263]), Cols: torch.Size([7263]), Values: torch.Size([7263])
# Graph - Rows: torch.Size([6850]), Cols: torch.Size([6850]), Values: torch.Size([6850])
# Graph - Rows: torch.Size([6858]), Cols: torch.Size([6858]), Values: torch.Size([6858])
# Graph - Rows: torch.Size([6815]), Cols: torch.Size([6815]), Values: torch.Size([6815])
# Graph - Rows: torch.Size([6797]), Cols: torch.Size([6797]), Values: torch.Size([6797])
# Graph - Rows: torch.Size([6403]), Cols: torch.Size([6403]), Values: torch.Size([6403])
# Graph - Rows: torch.Size([7028]), Cols: torch.Size([7028]), Values: torch.Size([7028])
# Graph - Rows: torch.Size([6895]), Cols: torch.Size([6895]), Values: torch.Size([6895])
# Graph - Rows: torch.Size([6389]), Cols: torch.Size([6389]), Values: torch.Size([6389])
# Graph - Rows: torch.Size([6855]), Cols: torch.Size([6855]), Values: torch.Size([6855])
# Graph - Rows: torch.Size([6856]), Cols: torch.Size([6856]), Values: torch.Size([6856])
# Graph - Rows: torch.Size([7066]), Cols: torch.Size([7066]), Values: torch.Size([7066])
# Graph - Rows: torch.Size([6985]), Cols: torch.Size([6985]), Values: torch.Size([6985])
# Graph - Rows: torch.Size([6623]), Cols: torch.Size([6623]), Values: torch.Size([6623])
# Graph - Rows: torch.Size([6701]), Cols: torch.Size([6701]), Values: torch.Size([6701])
# Graph - Rows: torch.Size([6904]), Cols: torch.Size([6904]), Values: torch.Size([6904])
# Graph - Rows: torch.Size([6693]), Cols: torch.Size([6693]), Values: torch.Size([6693])
# Graph - Rows: torch.Size([6998]), Cols: torch.Size([6998]), Values: torch.Size([6998])
# Graph - Rows: torch.Size([6817]), Cols: torch.Size([6817]), Values: torch.Size([6817])
# Graph - Rows: torch.Size([6873]), Cols: torch.Size([6873]), Values: torch.Size([6873])
# Graph - Rows: torch.Size([6407]), Cols: torch.Size([6407]), Values: torch.Size([6407])
# Graph - Rows: torch.Size([6966]), Cols: torch.Size([6966]), Values: torch.Size([6966])
# Graph - Rows: torch.Size([6498]), Cols: torch.Size([6498]), Values: torch.Size([6498])
# Graph - Rows: torch.Size([6480]), Cols: torch.Size([6480]), Values: torch.Size([6480])
# Graph - Rows: torch.Size([6669]), Cols: torch.Size([6669]), Values: torch.Size([6669])
# Graph - Rows: torch.Size([7034]), Cols: torch.Size([7034]), Values: torch.Size([7034])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([7106]), Cols: torch.Size([7106]), Values: torch.Size([7106])
# Graph - Rows: torch.Size([6859]), Cols: torch.Size([6859]), Values: torch.Size([6859])
# Graph - Rows: torch.Size([6339]), Cols: torch.Size([6339]), Values: torch.Size([6339])
# Graph - Rows: torch.Size([7157]), Cols: torch.Size([7157]), Values: torch.Size([7157])
# Graph - Rows: torch.Size([6950]), Cols: torch.Size([6950]), Values: torch.Size([6950])
# Graph - Rows: torch.Size([6956]), Cols: torch.Size([6956]), Values: torch.Size([6956])
# Graph - Rows: torch.Size([6444]), Cols: torch.Size([6444]), Values: torch.Size([6444])
# Graph - Rows: torch.Size([6706]), Cols: torch.Size([6706]), Values: torch.Size([6706])
# Graph - Rows: torch.Size([6682]), Cols: torch.Size([6682]), Values: torch.Size([6682])
# Graph - Rows: torch.Size([6816]), Cols: torch.Size([6816]), Values: torch.Size([6816])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([7250]), Cols: torch.Size([7250]), Values: torch.Size([7250])
# Graph - Rows: torch.Size([7251]), Cols: torch.Size([7251]), Values: torch.Size([7251])
# Graph - Rows: torch.Size([6615]), Cols: torch.Size([6615]), Values: torch.Size([6615])
# Graph - Rows: torch.Size([7236]), Cols: torch.Size([7236]), Values: torch.Size([7236])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([7087]), Cols: torch.Size([7087]), Values: torch.Size([7087])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([6916]), Cols: torch.Size([6916]), Values: torch.Size([6916])
# Graph - Rows: torch.Size([6942]), Cols: torch.Size([6942]), Values: torch.Size([6942])
# Graph - Rows: torch.Size([6767]), Cols: torch.Size([6767]), Values: torch.Size([6767])
# Graph - Rows: torch.Size([7144]), Cols: torch.Size([7144]), Values: torch.Size([7144])
# Graph - Rows: torch.Size([6737]), Cols: torch.Size([6737]), Values: torch.Size([6737])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([6574]), Cols: torch.Size([6574]), Values: torch.Size([6574])
# Graph - Rows: torch.Size([2845]), Cols: torch.Size([2845]), Values: torch.Size([2845])
# 2024-07-31 07:27:42,444 - stopping_criterion - recpack - INFO - StoppingCriterion has value 0.7167042486140811, which is worse than previous iterations.
# 2024-07-31 07:27:42,446 - base - recpack - INFO - Evaluation at end of 4 took 195.49 s.
# 2024-07-31 07:27:42,781 - base - recpack - INFO - Fitting LightGCNAlgorithm complete - Took 1.11e+03s
# Graph - Rows: torch.Size([6752]), Cols: torch.Size([6752]), Values: torch.Size([6752])
# Graph - Rows: torch.Size([6361]), Cols: torch.Size([6361]), Values: torch.Size([6361])
# Graph - Rows: torch.Size([6575]), Cols: torch.Size([6575]), Values: torch.Size([6575])
# Graph - Rows: torch.Size([6928]), Cols: torch.Size([6928]), Values: torch.Size([6928])
# Graph - Rows: torch.Size([7263]), Cols: torch.Size([7263]), Values: torch.Size([7263])
# Graph - Rows: torch.Size([6850]), Cols: torch.Size([6850]), Values: torch.Size([6850])
# Graph - Rows: torch.Size([6858]), Cols: torch.Size([6858]), Values: torch.Size([6858])
# Graph - Rows: torch.Size([6815]), Cols: torch.Size([6815]), Values: torch.Size([6815])
# Graph - Rows: torch.Size([6797]), Cols: torch.Size([6797]), Values: torch.Size([6797])
# Graph - Rows: torch.Size([6403]), Cols: torch.Size([6403]), Values: torch.Size([6403])
# Graph - Rows: torch.Size([7028]), Cols: torch.Size([7028]), Values: torch.Size([7028])
# Graph - Rows: torch.Size([6895]), Cols: torch.Size([6895]), Values: torch.Size([6895])
# Graph - Rows: torch.Size([6389]), Cols: torch.Size([6389]), Values: torch.Size([6389])
# Graph - Rows: torch.Size([6855]), Cols: torch.Size([6855]), Values: torch.Size([6855])
# Graph - Rows: torch.Size([6856]), Cols: torch.Size([6856]), Values: torch.Size([6856])
# Graph - Rows: torch.Size([7066]), Cols: torch.Size([7066]), Values: torch.Size([7066])
# Graph - Rows: torch.Size([6985]), Cols: torch.Size([6985]), Values: torch.Size([6985])
# Graph - Rows: torch.Size([6623]), Cols: torch.Size([6623]), Values: torch.Size([6623])
# Graph - Rows: torch.Size([6701]), Cols: torch.Size([6701]), Values: torch.Size([6701])
# Graph - Rows: torch.Size([6904]), Cols: torch.Size([6904]), Values: torch.Size([6904])
# Graph - Rows: torch.Size([6693]), Cols: torch.Size([6693]), Values: torch.Size([6693])
# Graph - Rows: torch.Size([6998]), Cols: torch.Size([6998]), Values: torch.Size([6998])
# Graph - Rows: torch.Size([6817]), Cols: torch.Size([6817]), Values: torch.Size([6817])
# Graph - Rows: torch.Size([6873]), Cols: torch.Size([6873]), Values: torch.Size([6873])
# Graph - Rows: torch.Size([6407]), Cols: torch.Size([6407]), Values: torch.Size([6407])
# Graph - Rows: torch.Size([6966]), Cols: torch.Size([6966]), Values: torch.Size([6966])
# Graph - Rows: torch.Size([6498]), Cols: torch.Size([6498]), Values: torch.Size([6498])
# Graph - Rows: torch.Size([6480]), Cols: torch.Size([6480]), Values: torch.Size([6480])
# Graph - Rows: torch.Size([6669]), Cols: torch.Size([6669]), Values: torch.Size([6669])
# Graph - Rows: torch.Size([7034]), Cols: torch.Size([7034]), Values: torch.Size([7034])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([7106]), Cols: torch.Size([7106]), Values: torch.Size([7106])
# Graph - Rows: torch.Size([6859]), Cols: torch.Size([6859]), Values: torch.Size([6859])
# Graph - Rows: torch.Size([6339]), Cols: torch.Size([6339]), Values: torch.Size([6339])
# Graph - Rows: torch.Size([7157]), Cols: torch.Size([7157]), Values: torch.Size([7157])
# Graph - Rows: torch.Size([6950]), Cols: torch.Size([6950]), Values: torch.Size([6950])
# Graph - Rows: torch.Size([6956]), Cols: torch.Size([6956]), Values: torch.Size([6956])
# Graph - Rows: torch.Size([6444]), Cols: torch.Size([6444]), Values: torch.Size([6444])
# Graph - Rows: torch.Size([6706]), Cols: torch.Size([6706]), Values: torch.Size([6706])
# Graph - Rows: torch.Size([6682]), Cols: torch.Size([6682]), Values: torch.Size([6682])
# Graph - Rows: torch.Size([6816]), Cols: torch.Size([6816]), Values: torch.Size([6816])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([7250]), Cols: torch.Size([7250]), Values: torch.Size([7250])
# Graph - Rows: torch.Size([7251]), Cols: torch.Size([7251]), Values: torch.Size([7251])
# Graph - Rows: torch.Size([6615]), Cols: torch.Size([6615]), Values: torch.Size([6615])
# Graph - Rows: torch.Size([7236]), Cols: torch.Size([7236]), Values: torch.Size([7236])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([7087]), Cols: torch.Size([7087]), Values: torch.Size([7087])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([6916]), Cols: torch.Size([6916]), Values: torch.Size([6916])
# Graph - Rows: torch.Size([6942]), Cols: torch.Size([6942]), Values: torch.Size([6942])
# Graph - Rows: torch.Size([6767]), Cols: torch.Size([6767]), Values: torch.Size([6767])
# Graph - Rows: torch.Size([7144]), Cols: torch.Size([7144]), Values: torch.Size([7144])
# Graph - Rows: torch.Size([6737]), Cols: torch.Size([6737]), Values: torch.Size([6737])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([6574]), Cols: torch.Size([6574]), Values: torch.Size([6574])
# Graph - Rows: torch.Size([2845]), Cols: torch.Size([2845]), Values: torch.Size([2845])
# Graph - Rows: torch.Size([1891951]), Cols: torch.Size([1891951]), Values: torch.Size([1891951])
# /tmp/ipykernel_173/999541933.py:81: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   user_indices = torch.tensor(user_indices).to(self.device)
# /tmp/ipykernel_173/999541933.py:82: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pos_item_indices = torch.tensor(pos_item_indices).to(self.device)
# /tmp/ipykernel_173/999541933.py:83: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   neg_item_indices = torch.tensor(neg_item_indices).to(self.device).squeeze()
# 2024-07-31 07:31:33,481 - base - recpack - INFO - Processed epoch 0 in 29.77 s.Batch Training Loss = 0.5605
# Graph - Rows: torch.Size([6752]), Cols: torch.Size([6752]), Values: torch.Size([6752])
# Graph - Rows: torch.Size([6361]), Cols: torch.Size([6361]), Values: torch.Size([6361])
# Graph - Rows: torch.Size([6575]), Cols: torch.Size([6575]), Values: torch.Size([6575])
# Graph - Rows: torch.Size([6928]), Cols: torch.Size([6928]), Values: torch.Size([6928])
# Graph - Rows: torch.Size([7263]), Cols: torch.Size([7263]), Values: torch.Size([7263])
# Graph - Rows: torch.Size([6850]), Cols: torch.Size([6850]), Values: torch.Size([6850])
# Graph - Rows: torch.Size([6858]), Cols: torch.Size([6858]), Values: torch.Size([6858])
# Graph - Rows: torch.Size([6815]), Cols: torch.Size([6815]), Values: torch.Size([6815])
# Graph - Rows: torch.Size([6797]), Cols: torch.Size([6797]), Values: torch.Size([6797])
# Graph - Rows: torch.Size([6403]), Cols: torch.Size([6403]), Values: torch.Size([6403])
# Graph - Rows: torch.Size([7028]), Cols: torch.Size([7028]), Values: torch.Size([7028])
# Graph - Rows: torch.Size([6895]), Cols: torch.Size([6895]), Values: torch.Size([6895])
# Graph - Rows: torch.Size([6389]), Cols: torch.Size([6389]), Values: torch.Size([6389])
# Graph - Rows: torch.Size([6855]), Cols: torch.Size([6855]), Values: torch.Size([6855])
# Graph - Rows: torch.Size([6856]), Cols: torch.Size([6856]), Values: torch.Size([6856])
# Graph - Rows: torch.Size([7066]), Cols: torch.Size([7066]), Values: torch.Size([7066])
# Graph - Rows: torch.Size([6985]), Cols: torch.Size([6985]), Values: torch.Size([6985])
# Graph - Rows: torch.Size([6623]), Cols: torch.Size([6623]), Values: torch.Size([6623])
# Graph - Rows: torch.Size([6701]), Cols: torch.Size([6701]), Values: torch.Size([6701])
# Graph - Rows: torch.Size([6904]), Cols: torch.Size([6904]), Values: torch.Size([6904])
# Graph - Rows: torch.Size([6693]), Cols: torch.Size([6693]), Values: torch.Size([6693])
# Graph - Rows: torch.Size([6998]), Cols: torch.Size([6998]), Values: torch.Size([6998])
# Graph - Rows: torch.Size([6817]), Cols: torch.Size([6817]), Values: torch.Size([6817])
# Graph - Rows: torch.Size([6873]), Cols: torch.Size([6873]), Values: torch.Size([6873])
# Graph - Rows: torch.Size([6407]), Cols: torch.Size([6407]), Values: torch.Size([6407])
# Graph - Rows: torch.Size([6966]), Cols: torch.Size([6966]), Values: torch.Size([6966])
# Graph - Rows: torch.Size([6498]), Cols: torch.Size([6498]), Values: torch.Size([6498])
# Graph - Rows: torch.Size([6480]), Cols: torch.Size([6480]), Values: torch.Size([6480])
# Graph - Rows: torch.Size([6669]), Cols: torch.Size([6669]), Values: torch.Size([6669])
# Graph - Rows: torch.Size([7034]), Cols: torch.Size([7034]), Values: torch.Size([7034])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([7106]), Cols: torch.Size([7106]), Values: torch.Size([7106])
# Graph - Rows: torch.Size([6859]), Cols: torch.Size([6859]), Values: torch.Size([6859])
# Graph - Rows: torch.Size([6339]), Cols: torch.Size([6339]), Values: torch.Size([6339])
# Graph - Rows: torch.Size([7157]), Cols: torch.Size([7157]), Values: torch.Size([7157])
# Graph - Rows: torch.Size([6950]), Cols: torch.Size([6950]), Values: torch.Size([6950])
# Graph - Rows: torch.Size([6956]), Cols: torch.Size([6956]), Values: torch.Size([6956])
# Graph - Rows: torch.Size([6444]), Cols: torch.Size([6444]), Values: torch.Size([6444])
# Graph - Rows: torch.Size([6706]), Cols: torch.Size([6706]), Values: torch.Size([6706])
# Graph - Rows: torch.Size([6682]), Cols: torch.Size([6682]), Values: torch.Size([6682])
# Graph - Rows: torch.Size([6816]), Cols: torch.Size([6816]), Values: torch.Size([6816])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([7250]), Cols: torch.Size([7250]), Values: torch.Size([7250])
# Graph - Rows: torch.Size([7251]), Cols: torch.Size([7251]), Values: torch.Size([7251])
# Graph - Rows: torch.Size([6615]), Cols: torch.Size([6615]), Values: torch.Size([6615])
# Graph - Rows: torch.Size([7236]), Cols: torch.Size([7236]), Values: torch.Size([7236])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([7087]), Cols: torch.Size([7087]), Values: torch.Size([7087])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([6916]), Cols: torch.Size([6916]), Values: torch.Size([6916])
# Graph - Rows: torch.Size([6942]), Cols: torch.Size([6942]), Values: torch.Size([6942])
# Graph - Rows: torch.Size([6767]), Cols: torch.Size([6767]), Values: torch.Size([6767])
# Graph - Rows: torch.Size([7144]), Cols: torch.Size([7144]), Values: torch.Size([7144])
# Graph - Rows: torch.Size([6737]), Cols: torch.Size([6737]), Values: torch.Size([6737])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([6574]), Cols: torch.Size([6574]), Values: torch.Size([6574])
# Graph - Rows: torch.Size([2845]), Cols: torch.Size([2845]), Values: torch.Size([2845])
# 2024-07-31 07:34:49,701 - stopping_criterion - recpack - INFO - StoppingCriterion has value 0.7026020523884761, which is better than previous iterations.
# 2024-07-31 07:34:49,702 - base - recpack - INFO - Model improved. Storing better model.
# 2024-07-31 07:34:50,298 - base - recpack - INFO - Evaluation at end of 0 took 196.81 s.
# Graph - Rows: torch.Size([1891951]), Cols: torch.Size([1891951]), Values: torch.Size([1891951])
# 2024-07-31 07:35:20,129 - base - recpack - INFO - Processed epoch 1 in 29.83 s.Batch Training Loss = 0.5317
# Graph - Rows: torch.Size([6752]), Cols: torch.Size([6752]), Values: torch.Size([6752])
# Graph - Rows: torch.Size([6361]), Cols: torch.Size([6361]), Values: torch.Size([6361])
# Graph - Rows: torch.Size([6575]), Cols: torch.Size([6575]), Values: torch.Size([6575])
# Graph - Rows: torch.Size([6928]), Cols: torch.Size([6928]), Values: torch.Size([6928])
# Graph - Rows: torch.Size([7263]), Cols: torch.Size([7263]), Values: torch.Size([7263])
# Graph - Rows: torch.Size([6850]), Cols: torch.Size([6850]), Values: torch.Size([6850])
# Graph - Rows: torch.Size([6858]), Cols: torch.Size([6858]), Values: torch.Size([6858])
# Graph - Rows: torch.Size([6815]), Cols: torch.Size([6815]), Values: torch.Size([6815])
# Graph - Rows: torch.Size([6797]), Cols: torch.Size([6797]), Values: torch.Size([6797])
# Graph - Rows: torch.Size([6403]), Cols: torch.Size([6403]), Values: torch.Size([6403])
# Graph - Rows: torch.Size([7028]), Cols: torch.Size([7028]), Values: torch.Size([7028])
# Graph - Rows: torch.Size([6895]), Cols: torch.Size([6895]), Values: torch.Size([6895])
# Graph - Rows: torch.Size([6389]), Cols: torch.Size([6389]), Values: torch.Size([6389])
# Graph - Rows: torch.Size([6855]), Cols: torch.Size([6855]), Values: torch.Size([6855])
# Graph - Rows: torch.Size([6856]), Cols: torch.Size([6856]), Values: torch.Size([6856])
# Graph - Rows: torch.Size([7066]), Cols: torch.Size([7066]), Values: torch.Size([7066])
# Graph - Rows: torch.Size([6985]), Cols: torch.Size([6985]), Values: torch.Size([6985])
# Graph - Rows: torch.Size([6623]), Cols: torch.Size([6623]), Values: torch.Size([6623])
# Graph - Rows: torch.Size([6701]), Cols: torch.Size([6701]), Values: torch.Size([6701])
# Graph - Rows: torch.Size([6904]), Cols: torch.Size([6904]), Values: torch.Size([6904])
# Graph - Rows: torch.Size([6693]), Cols: torch.Size([6693]), Values: torch.Size([6693])
# Graph - Rows: torch.Size([6998]), Cols: torch.Size([6998]), Values: torch.Size([6998])
# Graph - Rows: torch.Size([6817]), Cols: torch.Size([6817]), Values: torch.Size([6817])
# Graph - Rows: torch.Size([6873]), Cols: torch.Size([6873]), Values: torch.Size([6873])
# Graph - Rows: torch.Size([6407]), Cols: torch.Size([6407]), Values: torch.Size([6407])
# Graph - Rows: torch.Size([6966]), Cols: torch.Size([6966]), Values: torch.Size([6966])
# Graph - Rows: torch.Size([6498]), Cols: torch.Size([6498]), Values: torch.Size([6498])
# Graph - Rows: torch.Size([6480]), Cols: torch.Size([6480]), Values: torch.Size([6480])
# Graph - Rows: torch.Size([6669]), Cols: torch.Size([6669]), Values: torch.Size([6669])
# Graph - Rows: torch.Size([7034]), Cols: torch.Size([7034]), Values: torch.Size([7034])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([7106]), Cols: torch.Size([7106]), Values: torch.Size([7106])
# Graph - Rows: torch.Size([6859]), Cols: torch.Size([6859]), Values: torch.Size([6859])
# Graph - Rows: torch.Size([6339]), Cols: torch.Size([6339]), Values: torch.Size([6339])
# Graph - Rows: torch.Size([7157]), Cols: torch.Size([7157]), Values: torch.Size([7157])
# Graph - Rows: torch.Size([6950]), Cols: torch.Size([6950]), Values: torch.Size([6950])
# Graph - Rows: torch.Size([6956]), Cols: torch.Size([6956]), Values: torch.Size([6956])
# Graph - Rows: torch.Size([6444]), Cols: torch.Size([6444]), Values: torch.Size([6444])
# Graph - Rows: torch.Size([6706]), Cols: torch.Size([6706]), Values: torch.Size([6706])
# Graph - Rows: torch.Size([6682]), Cols: torch.Size([6682]), Values: torch.Size([6682])
# Graph - Rows: torch.Size([6816]), Cols: torch.Size([6816]), Values: torch.Size([6816])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([7250]), Cols: torch.Size([7250]), Values: torch.Size([7250])
# Graph - Rows: torch.Size([7251]), Cols: torch.Size([7251]), Values: torch.Size([7251])
# Graph - Rows: torch.Size([6615]), Cols: torch.Size([6615]), Values: torch.Size([6615])
# Graph - Rows: torch.Size([7236]), Cols: torch.Size([7236]), Values: torch.Size([7236])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([7087]), Cols: torch.Size([7087]), Values: torch.Size([7087])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([6916]), Cols: torch.Size([6916]), Values: torch.Size([6916])
# Graph - Rows: torch.Size([6942]), Cols: torch.Size([6942]), Values: torch.Size([6942])
# Graph - Rows: torch.Size([6767]), Cols: torch.Size([6767]), Values: torch.Size([6767])
# Graph - Rows: torch.Size([7144]), Cols: torch.Size([7144]), Values: torch.Size([7144])
# Graph - Rows: torch.Size([6737]), Cols: torch.Size([6737]), Values: torch.Size([6737])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([6574]), Cols: torch.Size([6574]), Values: torch.Size([6574])
# Graph - Rows: torch.Size([2845]), Cols: torch.Size([2845]), Values: torch.Size([2845])
# 2024-07-31 07:38:36,334 - stopping_criterion - recpack - INFO - StoppingCriterion has value 0.7076244296152613, which is worse than previous iterations.
# 2024-07-31 07:38:36,336 - base - recpack - INFO - Evaluation at end of 1 took 196.21 s.
# Graph - Rows: torch.Size([1891951]), Cols: torch.Size([1891951]), Values: torch.Size([1891951])
# 2024-07-31 07:39:05,961 - base - recpack - INFO - Processed epoch 2 in 29.62 s.Batch Training Loss = 0.5284
# Graph - Rows: torch.Size([6752]), Cols: torch.Size([6752]), Values: torch.Size([6752])
# Graph - Rows: torch.Size([6361]), Cols: torch.Size([6361]), Values: torch.Size([6361])
# Graph - Rows: torch.Size([6575]), Cols: torch.Size([6575]), Values: torch.Size([6575])
# Graph - Rows: torch.Size([6928]), Cols: torch.Size([6928]), Values: torch.Size([6928])
# Graph - Rows: torch.Size([7263]), Cols: torch.Size([7263]), Values: torch.Size([7263])
# Graph - Rows: torch.Size([6850]), Cols: torch.Size([6850]), Values: torch.Size([6850])
# Graph - Rows: torch.Size([6858]), Cols: torch.Size([6858]), Values: torch.Size([6858])
# Graph - Rows: torch.Size([6815]), Cols: torch.Size([6815]), Values: torch.Size([6815])
# Graph - Rows: torch.Size([6797]), Cols: torch.Size([6797]), Values: torch.Size([6797])
# Graph - Rows: torch.Size([6403]), Cols: torch.Size([6403]), Values: torch.Size([6403])
# Graph - Rows: torch.Size([7028]), Cols: torch.Size([7028]), Values: torch.Size([7028])
# Graph - Rows: torch.Size([6895]), Cols: torch.Size([6895]), Values: torch.Size([6895])
# Graph - Rows: torch.Size([6389]), Cols: torch.Size([6389]), Values: torch.Size([6389])
# Graph - Rows: torch.Size([6855]), Cols: torch.Size([6855]), Values: torch.Size([6855])
# Graph - Rows: torch.Size([6856]), Cols: torch.Size([6856]), Values: torch.Size([6856])
# Graph - Rows: torch.Size([7066]), Cols: torch.Size([7066]), Values: torch.Size([7066])
# Graph - Rows: torch.Size([6985]), Cols: torch.Size([6985]), Values: torch.Size([6985])
# Graph - Rows: torch.Size([6623]), Cols: torch.Size([6623]), Values: torch.Size([6623])
# Graph - Rows: torch.Size([6701]), Cols: torch.Size([6701]), Values: torch.Size([6701])
# Graph - Rows: torch.Size([6904]), Cols: torch.Size([6904]), Values: torch.Size([6904])
# Graph - Rows: torch.Size([6693]), Cols: torch.Size([6693]), Values: torch.Size([6693])
# Graph - Rows: torch.Size([6998]), Cols: torch.Size([6998]), Values: torch.Size([6998])
# ...
# Graph - Rows: torch.Size([6575]), Cols: torch.Size([6575]), Values: torch.Size([6575])
# Graph - Rows: torch.Size([6928]), Cols: torch.Size([6928]), Values: torch.Size([6928])
# Graph - Rows: torch.Size([7263]), Cols: torch.Size([7263]), Values: torch.Size([7263])
# Graph - Rows: torch.Size([6850]), Cols: torch.Size([6850]), Values: torch.Size([6850])
# Graph - Rows: torch.Size([6858]), Cols: torch.Size([6858]), Values: torch.Size([6858])
# Graph - Rows: torch.Size([6815]), Cols: torch.Size([6815]), Values: torch.Size([6815])
# Graph - Rows: torch.Size([6797]), Cols: torch.Size([6797]), Values: torch.Size([6797])
# Graph - Rows: torch.Size([6403]), Cols: torch.Size([6403]), Values: torch.Size([6403])
# Graph - Rows: torch.Size([7028]), Cols: torch.Size([7028]), Values: torch.Size([7028])
# Graph - Rows: torch.Size([6895]), Cols: torch.Size([6895]), Values: torch.Size([6895])
# Graph - Rows: torch.Size([6389]), Cols: torch.Size([6389]), Values: torch.Size([6389])
# Graph - Rows: torch.Size([6855]), Cols: torch.Size([6855]), Values: torch.Size([6855])
# Graph - Rows: torch.Size([6856]), Cols: torch.Size([6856]), Values: torch.Size([6856])
# Graph - Rows: torch.Size([7066]), Cols: torch.Size([7066]), Values: torch.Size([7066])
# Graph - Rows: torch.Size([6985]), Cols: torch.Size([6985]), Values: torch.Size([6985])
# Graph - Rows: torch.Size([6623]), Cols: torch.Size([6623]), Values: torch.Size([6623])
# Graph - Rows: torch.Size([6701]), Cols: torch.Size([6701]), Values: torch.Size([6701])
# Graph - Rows: torch.Size([6904]), Cols: torch.Size([6904]), Values: torch.Size([6904])
# Graph - Rows: torch.Size([6693]), Cols: torch.Size([6693]), Values: torch.Size([6693])
# Graph - Rows: torch.Size([6998]), Cols: torch.Size([6998]), Values: torch.Size([6998])
# Graph - Rows: torch.Size([6817]), Cols: torch.Size([6817]), Values: torch.Size([6817])
# Graph - Rows: torch.Size([6873]), Cols: torch.Size([6873]), Values: torch.Size([6873])
# Graph - Rows: torch.Size([6407]), Cols: torch.Size([6407]), Values: torch.Size([6407])
# Graph - Rows: torch.Size([6966]), Cols: torch.Size([6966]), Values: torch.Size([6966])
# Graph - Rows: torch.Size([6498]), Cols: torch.Size([6498]), Values: torch.Size([6498])
# Graph - Rows: torch.Size([6480]), Cols: torch.Size([6480]), Values: torch.Size([6480])
# Graph - Rows: torch.Size([6669]), Cols: torch.Size([6669]), Values: torch.Size([6669])
# Graph - Rows: torch.Size([7034]), Cols: torch.Size([7034]), Values: torch.Size([7034])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([7106]), Cols: torch.Size([7106]), Values: torch.Size([7106])
# Graph - Rows: torch.Size([6859]), Cols: torch.Size([6859]), Values: torch.Size([6859])
# Graph - Rows: torch.Size([6339]), Cols: torch.Size([6339]), Values: torch.Size([6339])
# Graph - Rows: torch.Size([7157]), Cols: torch.Size([7157]), Values: torch.Size([7157])
# Graph - Rows: torch.Size([6950]), Cols: torch.Size([6950]), Values: torch.Size([6950])
# Graph - Rows: torch.Size([6956]), Cols: torch.Size([6956]), Values: torch.Size([6956])
# Graph - Rows: torch.Size([6444]), Cols: torch.Size([6444]), Values: torch.Size([6444])
# Graph - Rows: torch.Size([6706]), Cols: torch.Size([6706]), Values: torch.Size([6706])
# Graph - Rows: torch.Size([6682]), Cols: torch.Size([6682]), Values: torch.Size([6682])
# Graph - Rows: torch.Size([6816]), Cols: torch.Size([6816]), Values: torch.Size([6816])
# Graph - Rows: torch.Size([6903]), Cols: torch.Size([6903]), Values: torch.Size([6903])
# Graph - Rows: torch.Size([7250]), Cols: torch.Size([7250]), Values: torch.Size([7250])
# Graph - Rows: torch.Size([7251]), Cols: torch.Size([7251]), Values: torch.Size([7251])
# Graph - Rows: torch.Size([6615]), Cols: torch.Size([6615]), Values: torch.Size([6615])
# Graph - Rows: torch.Size([7236]), Cols: torch.Size([7236]), Values: torch.Size([7236])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([7087]), Cols: torch.Size([7087]), Values: torch.Size([7087])
# Graph - Rows: torch.Size([6769]), Cols: torch.Size([6769]), Values: torch.Size([6769])
# Graph - Rows: torch.Size([6916]), Cols: torch.Size([6916]), Values: torch.Size([6916])
# Graph - Rows: torch.Size([6942]), Cols: torch.Size([6942]), Values: torch.Size([6942])
# Graph - Rows: torch.Size([6767]), Cols: torch.Size([6767]), Values: torch.Size([6767])
# Graph - Rows: torch.Size([7144]), Cols: torch.Size([7144]), Values: torch.Size([7144])
# Graph - Rows: torch.Size([6737]), Cols: torch.Size([6737]), Values: torch.Size([6737])
# Graph - Rows: torch.Size([6944]), Cols: torch.Size([6944]), Values: torch.Size([6944])
# Graph - Rows: torch.Size([6574]), Cols: torch.Size([6574]), Values: torch.Size([6574])
# Graph - Rows: torch.Size([2845]), Cols: torch.Size([2845]), Values: torch.Size([2845])
# 2024-07-31 11:09:54,828 - stopping_criterion - recpack - INFO - StoppingCriterion has value 0.7446079138390077, which is worse than previous iterations.
# 2024-07-31 11:09:54,830 - base - recpack - INFO - Evaluation at end of 4 took 198.44 s.
# 2024-07-31 11:09:55,207 - base - recpack - INFO - Fitting LightGCNAlgorithm complete - Took 1.14e+03s
# Graph - Rows: torch.Size([7149]), Cols: torch.Size([7149]), Values: torch.Size([7149])
# Graph - Rows: torch.Size([6927]), Cols: torch.Size([6927]), Values: torch.Size([6927])
# Graph - Rows: torch.Size([7030]), Cols: torch.Size([7030]), Values: torch.Size([7030])
# Graph - Rows: torch.Size([6960]), Cols: torch.Size([6960]), Values: torch.Size([6960])
# Graph - Rows: torch.Size([6951]), Cols: torch.Size([6951]), Values: torch.Size([6951])
# Graph - Rows: torch.Size([6737]), Cols: torch.Size([6737]), Values: torch.Size([6737])
# Graph - Rows: torch.Size([6878]), Cols: torch.Size([6878]), Values: torch.Size([6878])
# Graph - Rows: torch.Size([6956]), Cols: torch.Size([6956]), Values: torch.Size([6956])
# Graph - Rows: torch.Size([6778]), Cols: torch.Size([6778]), Values: torch.Size([6778])
# Graph - Rows: torch.Size([6607]), Cols: torch.Size([6607]), Values: torch.Size([6607])
# Graph - Rows: torch.Size([7020]), Cols: torch.Size([7020]), Values: torch.Size([7020])
# Graph - Rows: torch.Size([6893]), Cols: torch.Size([6893]), Values: torch.Size([6893])
# Graph - Rows: torch.Size([6797]), Cols: torch.Size([6797]), Values: torch.Size([6797])
# Graph - Rows: torch.Size([6554]), Cols: torch.Size([6554]), Values: torch.Size([6554])
# Graph - Rows: torch.Size([6719]), Cols: torch.Size([6719]), Values: torch.Size([6719])
# Graph - Rows: torch.Size([6895]), Cols: torch.Size([6895]), Values: torch.Size([6895])
# Graph - Rows: torch.Size([6471]), Cols: torch.Size([6471]), Values: torch.Size([6471])
# Graph - Rows: torch.Size([7021]), Cols: torch.Size([7021]), Values: torch.Size([7021])
# Graph - Rows: torch.Size([6583]), Cols: torch.Size([6583]), Values: torch.Size([6583])
# Graph - Rows: torch.Size([7001]), Cols: torch.Size([7001]), Values: torch.Size([7001])
# Graph - Rows: torch.Size([6656]), Cols: torch.Size([6656]), Values: torch.Size([6656])
# Graph - Rows: torch.Size([6627]), Cols: torch.Size([6627]), Values: torch.Size([6627])
# Graph - Rows: torch.Size([6454]), Cols: torch.Size([6454]), Values: torch.Size([6454])
# Graph - Rows: torch.Size([6699]), Cols: torch.Size([6699]), Values: torch.Size([6699])
# Graph - Rows: torch.Size([6493]), Cols: torch.Size([6493]), Values: torch.Size([6493])
# Graph - Rows: torch.Size([6799]), Cols: torch.Size([6799]), Values: torch.Size([6799])
# Graph - Rows: torch.Size([6787]), Cols: torch.Size([6787]), Values: torch.Size([6787])
# Graph - Rows: torch.Size([6968]), Cols: torch.Size([6968]), Values: torch.Size([6968])
# Graph - Rows: torch.Size([6574]), Cols: torch.Size([6574]), Values: torch.Size([6574])
# Graph - Rows: torch.Size([6583]), Cols: torch.Size([6583]), Values: torch.Size([6583])
# Graph - Rows: torch.Size([6860]), Cols: torch.Size([6860]), Values: torch.Size([6860])
# Graph - Rows: torch.Size([6726]), Cols: torch.Size([6726]), Values: torch.Size([6726])
# Graph - Rows: torch.Size([6581]), Cols: torch.Size([6581]), Values: torch.Size([6581])
# Graph - Rows: torch.Size([6466]), Cols: torch.Size([6466]), Values: torch.Size([6466])
# Graph - Rows: torch.Size([6471]), Cols: torch.Size([6471]), Values: torch.Size([6471])
# Graph - Rows: torch.Size([6329]), Cols: torch.Size([6329]), Values: torch.Size([6329])
# Graph - Rows: torch.Size([6595]), Cols: torch.Size([6595]), Values: torch.Size([6595])
# Graph - Rows: torch.Size([6957]), Cols: torch.Size([6957]), Values: torch.Size([6957])
# Graph - Rows: torch.Size([6742]), Cols: torch.Size([6742]), Values: torch.Size([6742])
# Graph - Rows: torch.Size([6472]), Cols: torch.Size([6472]), Values: torch.Size([6472])
# Graph - Rows: torch.Size([6320]), Cols: torch.Size([6320]), Values: torch.Size([6320])
# Graph - Rows: torch.Size([6867]), Cols: torch.Size([6867]), Values: torch.Size([6867])
# Graph - Rows: torch.Size([6513]), Cols: torch.Size([6513]), Values: torch.Size([6513])
# Graph - Rows: torch.Size([6887]), Cols: torch.Size([6887]), Values: torch.Size([6887])
# Graph - Rows: torch.Size([6905]), Cols: torch.Size([6905]), Values: torch.Size([6905])
# Graph - Rows: torch.Size([7080]), Cols: torch.Size([7080]), Values: torch.Size([7080])
# Graph - Rows: torch.Size([6665]), Cols: torch.Size([6665]), Values: torch.Size([6665])
# Graph - Rows: torch.Size([6881]), Cols: torch.Size([6881]), Values: torch.Size([6881])
# Graph - Rows: torch.Size([6670]), Cols: torch.Size([6670]), Values: torch.Size([6670])
# Graph - Rows: torch.Size([6686]), Cols: torch.Size([6686]), Values: torch.Size([6686])
# Graph - Rows: torch.Size([6544]), Cols: torch.Size([6544]), Values: torch.Size([6544])
# Graph - Rows: torch.Size([6724]), Cols: torch.Size([6724]), Values: torch.Size([6724])
# Graph - Rows: torch.Size([6447]), Cols: torch.Size([6447]), Values: torch.Size([6447])
# Graph - Rows: torch.Size([6780]), Cols: torch.Size([6780]), Values: torch.Size([6780])
# Graph - Rows: torch.Size([7394]), Cols: torch.Size([7394]), Values: torch.Size([7394])
# Graph - Rows: torch.Size([6676]), Cols: torch.Size([6676]), Values: torch.Size([6676])
# Graph - Rows: torch.Size([7103]), Cols: torch.Size([7103]), Values: torch.Size([7103])
# Graph - Rows: torch.Size([6441]), Cols: torch.Size([6441]), Values: torch.Size([6441])
# Graph - Rows: torch.Size([7100]), Cols: torch.Size([7100]), Values: torch.Size([7100])
# Graph - Rows: torch.Size([6754]), Cols: torch.Size([6754]), Values: torch.Size([6754])
# Graph - Rows: torch.Size([6499]), Cols: torch.Size([6499]), Values: torch.Size([6499])
# Graph - Rows: torch.Size([6505]), Cols: torch.Size([6505]), Values: torch.Size([6505])
# Graph - Rows: torch.Size([6970]), Cols: torch.Size([6970]), Values: torch.Size([6970])
# Graph - Rows: torch.Size([6296]), Cols: torch.Size([6296]), Values: torch.Size([6296])
# Graph - Rows: torch.Size([6667]), Cols: torch.Size([6667]), Values: torch.Size([6667])
# Graph - Rows: torch.Size([6797]), Cols: torch.Size([6797]), Values: torch.Size([6797])
# Graph - Rows: torch.Size([6981]), Cols: torch.Size([6981]), Values: torch.Size([6981])
# Graph - Rows: torch.Size([6466]), Cols: torch.Size([6466]), Values: torch.Size([6466])
# Graph - Rows: torch.Size([7250]), Cols: torch.Size([7250]), Values: torch.Size([7250])
# Graph - Rows: torch.Size([7147]), Cols: torch.Size([7147]), Values: torch.Size([7147])
# Graph - Rows: torch.Size([6667]), Cols: torch.Size([6667]), Values: torch.Size([6667])
# Graph - Rows: torch.Size([6491]), Cols: torch.Size([6491]), Values: torch.Size([6491])
# Graph - Rows: torch.Size([6613]), Cols: torch.Size([6613]), Values: torch.Size([6613])
# Graph - Rows: torch.Size([7098]), Cols: torch.Size([7098]), Values: torch.Size([7098])
# Graph - Rows: torch.Size([6706]), Cols: torch.Size([6706]), Values: torch.Size([6706])
# Graph - Rows: torch.Size([6581]), Cols: torch.Size([6581]), Values: torch.Size([6581])
# Graph - Rows: torch.Size([7025]), Cols: torch.Size([7025]), Values: torch.Size([7025])
# Graph - Rows: torch.Size([7016]), Cols: torch.Size([7016]), Values: torch.Size([7016])
# Graph - Rows: torch.Size([6972]), Cols: torch.Size([6972]), Values: torch.Size([6972])
# Graph - Rows: torch.Size([6807]), Cols: torch.Size([6807]), Values: torch.Size([6807])
# Graph - Rows: torch.Size([6502]), Cols: torch.Size([6502]), Values: torch.Size([6502])
# Graph - Rows: torch.Size([6750]), Cols: torch.Size([6750]), Values: torch.Size([6750])
# Graph - Rows: torch.Size([6509]), Cols: torch.Size([6509]), Values: torch.Size([6509])
# Graph - Rows: torch.Size([6672]), Cols: torch.Size([6672]), Values: torch.Size([6672])
# Graph - Rows: torch.Size([6847]), Cols: torch.Size([6847]), Values: torch.Size([6847])
# Graph - Rows: torch.Size([6815]), Cols: torch.Size([6815]), Values: torch.Size([6815])
# Graph - Rows: torch.Size([6789]), Cols: torch.Size([6789]), Values: torch.Size([6789])
# Graph - Rows: torch.Size([6792]), Cols: torch.Size([6792]), Values: torch.Size([6792])
# Graph - Rows: torch.Size([6836]), Cols: torch.Size([6836]), Values: torch.Size([6836])
# Graph - Rows: torch.Size([6929]), Cols: torch.Size([6929]), Values: torch.Size([6929])
# Graph - Rows: torch.Size([6582]), Cols: torch.Size([6582]), Values: torch.Size([6582])
# Graph - Rows: torch.Size([6525]), Cols: torch.Size([6525]), Values: torch.Size([6525])
# Graph - Rows: torch.Size([6766]), Cols: torch.Size([6766]), Values: torch.Size([6766])
# Graph - Rows: torch.Size([6690]), Cols: torch.Size([6690]), Values: torch.Size([6690])
# Graph - Rows: torch.Size([6338]), Cols: torch.Size([6338]), Values: torch.Size([6338])
# Graph - Rows: torch.Size([6572]), Cols: torch.Size([6572]), Values: torch.Size([6572])
# Graph - Rows: torch.Size([6555]), Cols: torch.Size([6555]), Values: torch.Size([6555])
# Graph - Rows: torch.Size([6806]), Cols: torch.Size([6806]), Values: torch.Size([6806])
# Graph - Rows: torch.Size([6741]), Cols: torch.Size([6741]), Values: torch.Size([6741])
# Graph - Rows: torch.Size([7040]), Cols: torch.Size([7040]), Values: torch.Size([7040])
# Graph - Rows: torch.Size([6458]), Cols: torch.Size([6458]), Values: torch.Size([6458])
# Graph - Rows: torch.Size([6471]), Cols: torch.Size([6471]), Values: torch.Size([6471])
# Graph - Rows: torch.Size([6108]), Cols: torch.Size([6108]), Values: torch.Size([6108])
# Graph - Rows: torch.Size([6816]), Cols: torch.Size([6816]), Values: torch.Size([6816])
# Graph - Rows: torch.Size([6284]), Cols: torch.Size([6284]), Values: torch.Size([6284])
# Graph - Rows: torch.Size([6651]), Cols: torch.Size([6651]), Values: torch.Size([6651])
# Graph - Rows: torch.Size([6408]), Cols: torch.Size([6408]), Values: torch.Size([6408])
# Graph - Rows: torch.Size([6456]), Cols: torch.Size([6456]), Values: torch.Size([6456])
# Graph - Rows: torch.Size([6546]), Cols: torch.Size([6546]), Values: torch.Size([6546])
# Graph - Rows: torch.Size([6747]), Cols: torch.Size([6747]), Values: torch.Size([6747])
# Graph - Rows: torch.Size([6442]), Cols: torch.Size([6442]), Values: torch.Size([6442])
# Graph - Rows: torch.Size([6465]), Cols: torch.Size([6465]), Values: torch.Size([6465])
# Graph - Rows: torch.Size([6916]), Cols: torch.Size([6916]), Values: torch.Size([6916])
# Graph - Rows: torch.Size([6747]), Cols: torch.Size([6747]), Values: torch.Size([6747])
# Graph - Rows: torch.Size([6860]), Cols: torch.Size([6860]), Values: torch.Size([6860])
# Graph - Rows: torch.Size([6250]), Cols: torch.Size([6250]), Values: torch.Size([6250])
# Graph - Rows: torch.Size([6536]), Cols: torch.Size([6536]), Values: torch.Size([6536])
# Graph - Rows: torch.Size([6912]), Cols: torch.Size([6912]), Values: torch.Size([6912])
# Graph - Rows: torch.Size([6715]), Cols: torch.Size([6715]), Values: torch.Size([6715])
# Graph - Rows: torch.Size([6650]), Cols: torch.Size([6650]), Values: torch.Size([6650])
# Graph - Rows: torch.Size([6735]), Cols: torch.Size([6735]), Values: torch.Size([6735])
# Graph - Rows: torch.Size([6564]), Cols: torch.Size([6564]), Values: torch.Size([6564])
# Graph - Rows: torch.Size([5266]), Cols: torch.Size([5266]), Values: torch.Size([5266])

# %% [markdown]
# ## Results

# %%
pipeline.get_metrics()
# Out:
#                                                     NDCGK_10  NDCGK_20  \
# LightGCNAlgorithm(batch_size=1024,embedding_dim...  0.018736  0.023259
#
#                                                     NDCGK_50  RecallK_10  \
# LightGCNAlgorithm(batch_size=1024,embedding_dim...  0.034909    0.026918
#
#                                                     RecallK_20  RecallK_50  \
# LightGCNAlgorithm(batch_size=1024,embedding_dim...    0.041416    0.086329
#
#                                                      HitK_10   HitK_20  \
# LightGCNAlgorithm(batch_size=1024,embedding_dim...  0.082021  0.131182
#
#                                                      HitK_50
# LightGCNAlgorithm(batch_size=1024,embedding_dim...  0.279164

# %%
pd.DataFrame.from_dict(pipeline.get_metrics()).T
# Out:
#             LightGCNAlgorithm(batch_size=1024,embedding_dim=100,keep_last=False,learning_rate=0.001,max_epochs=5,max_iter_no_change=5,min_improvement=0.01,n_layers=3,predict_topK=None,reg_weight=1e-05,save_best_to_file=False,seed=1033913625,stop_early=True,stopping_criterion=<recpack.algorithms.stopping_criterion.StoppingCriterion object at 0x7f8f1c12da90>,validation_sample_size=None)
# NDCGK_10                                             0.018736
# NDCGK_20                                             0.023259
# NDCGK_50                                             0.034909
# RecallK_10                                           0.026918
# RecallK_20                                           0.041416
# RecallK_50                                           0.086329
# HitK_10                                              0.082021
# HitK_20                                              0.131182
# HitK_50                                              0.279164
